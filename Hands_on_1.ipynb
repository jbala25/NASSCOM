# %%
import pandas as pd

# Convert raw_sensor_data to a pandas DataFrame
df_sensor_data = pd.DataFrame(raw_sensor_data, columns=['Timestamp', 'Device_ID', 'Device_Type', 'Location', 'Value'])

# Display the first 5 rows of the DataFrame
print("\nPandas DataFrame:")
display(df_sensor_data.head())
# Out:
# Pandas DataFrame:
#              Timestamp Device_ID  Device_Type     Location    Value
# 0  2026-06-10 01:34:20    DEV001        Light  Living Room    29.02
# 1  2026-06-10 08:18:20    DEV002  Temperature      Bedroom    21.40
# 2  2026-06-10 11:03:20    DEV003     Pressure     Bathroom  1009.69
# 3  2026-06-10 06:21:20    DEV004     Pressure      Bedroom  1023.79
# 4  2026-06-09 22:23:20    DEV005     Pressure      Bedroom   986.63
